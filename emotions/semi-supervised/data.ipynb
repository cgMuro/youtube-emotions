# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv('./data/labeled/youtube_labeled.csv', usecols=['text', 'emotion'])

df
# Out:
#                                                   text  \
# 0    New YouTube idea : Logan, Mike and David switc...
# 1    You can tell he matured and changed so much, s...
# 2    Ok,I’m sorry Logan,I’ve been thinking,and I ca...
# 3    After watching him now I feel like he did not ...
# 4    Literally 99% won’t see this but have a wonder...
# ..                                                 ...
# 127  Do a crossover with Mr Beast and visit his new...
# 128  Take your boat to MrBeast's Island "JEFF" and ...
# 129  Wow I can’t believe this All happened in one year
# 130                 i fucking hate u and your content!
# 131  that is so fucking heart broking, I'm so sorry...
#
#                         emotion
# 0                 neutral/other
# 1                      positive
# 2                      positive
# 3                      positive
# 4                      positive
# ..                          ...
# 127  constructive feedback/idea
# 128  constructive feedback/idea
# 129               neutral/other
# 130                    negative
# 131                     sadness
#
# [132 rows x 2 columns]

# %% [markdown]
# # Emotions
#
# The categories that will be used for the emotions:
# * Neutral/other
# * Negative (anger/hate/disgust)
# * Positive (joy/happiness/amusement/love)
# * Constructive feedback/idea
# * Sadness
#
# <br>
#
# What needs to be done:
# * check what emotions are in the dataframe
# * count the number of examples for each emotion

# %%
df['emotion'].unique()
# Out:
# array(['neutral/other', 'positive', 'constructive feedback/idea',
#        'sadness', 'negative'], dtype=object)

# %%
plt.figure(figsize=(15, 7), dpi=100)
sns.countplot(x='emotion', data=df)
plt.show()

# %%
df.groupby('emotion').count()
# Out:
#                             text
# emotion
# constructive feedback/idea    25
# negative                      25
# neutral/other                 25
# positive                      32
# sadness                       25

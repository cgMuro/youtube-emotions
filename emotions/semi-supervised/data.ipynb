# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv('./data/labeled/youtube_labeled.csv', usecols=['text', 'emotion'])

df
# Out:
#                                                   text  \
# 0    New YouTube idea : Logan, Mike and David switc...
# 1    You can tell he matured and changed so much, s...
# 2    Ok,I’m sorry Logan,I’ve been thinking,and I ca...
# 3    After watching him now I feel like he did not ...
# 4    Literally 99% won’t see this but have a wonder...
# ..                                                 ...
# 700  At 43:46, what if you chose a different slice ...
# 701  Is Taylor really that unpopular? (@ 38:20)\nWe...
# 702  just in-case anyone was wondering the program ...
# 703  Applied math, which is the same thing as physi...
# 704  Arrr, finally I found a key to understand mult...
#
#                         emotion
# 0                 neutral/other
# 1                      positive
# 2                      positive
# 3                      positive
# 4                      positive
# ..                          ...
# 700  constructive feedback/idea
# 701               neutral/other
# 702               neutral/other
# 703               neutral/other
# 704               neutral/other
#
# [705 rows x 2 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Handle Duplicates

# %%
df.duplicated(subset=['text'], keep='first').sum()
# Out:
# 46

# %%
# Drop duplicates
df.drop_duplicates(subset=['text'], keep='first', inplace=True)

df.duplicated(subset=['text'], keep='first').sum()
# Out:
# 0

# %% [markdown]
# # Emotions
#
# The categories that will be used for the emotions:
# * Neutral/other
# * Negative (anger/hate/disgust)
# * Positive (joy/happiness/amusement/love)
# * Constructive feedback/idea
# * Sadness
#
# <br>
#
# What needs to be done:
# * check what emotions are in the dataframe
# * count the number of examples for each emotion

# %%
df['emotion'].unique()
# Out:
# array(['neutral/other', 'positive', 'constructive feedback/idea',
#        'sadness', 'negative'], dtype=object)

# %%
plt.figure(figsize=(15, 7), dpi=100)
sns.countplot(x='emotion', data=df)
plt.show()

# %%
df.groupby('emotion').count()
# Out:
#                             text
# emotion
# constructive feedback/idea    69
# negative                      78
# neutral/other                240
# positive                     205
# sadness                       67

# %% [markdown]
# ## Save Edited Dataset

# %%
df.to_csv('./data/labeled/youtube_labeled_edited.csv', columns=['text', 'emotion'])

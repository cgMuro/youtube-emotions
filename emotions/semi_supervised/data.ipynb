# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv('./data/youtube_labeled.csv', usecols=['text', 'emotion'])

df
# Out:
#                                                   text        emotion
# 0    Roses are red,\nMy name is not Dave, \nThis po...       positive
# 1    He protecc\nHe attacc\nBut most importantly\nH...       positive
# 2    New YouTube idea : Logan, Mike and David switc...  neutral/other
# 3    I really want to do the treadmill in the pool ...       positive
# 4    You can tell he matured and changed so much, s...           love
# ..                                                 ...            ...
# 115         I'm sad, i know yeah.\n\nRest In peace. 🕊️        sadness
# 116                           I'm so sad that it ended        sadness
# 117       It's sad that know we think only about money        sadness
# 118                              2021 still no vlog :(        sadness
# 119                It's been 8 months guys. Im scared.        sadness
#
# [120 rows x 2 columns]

# %% [markdown]
# # Emotions
#
# The categories that will be used for the emotions:
# * Neutral/other
# * Negative (anger/hate/disgust)
# * Positive (joy/happiness/amusement)
# * Constructive feedback/idea
# * Sadness
# * Love
#
# <br>
#
# What needs to be done:
# * check what emotions are in the dataframe
# * count the number of examples for each emotion

# %%
df['emotion'].unique()
# Out:
# array(['positive', 'neutral/other', 'love', 'constructive feedback/idea',
#        'sadness', 'negative'], dtype=object)

# %%
plt.figure(figsize=(15, 7), dpi=100)
sns.countplot(x='emotion', data=df)
plt.show()

# %%
df.groupby('emotion').count()
# Out:
#                             text
# emotion
# constructive feedback/idea    20
# love                          20
# negative                      20
# neutral/other                 20
# positive                      20
# sadness                       20

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv('./data/labeled/youtube_labeled.csv', usecols=['text', 'emotion'])

df
# Out:
#                                                   text  \
# 0    Roses are red,\nMy name is not Dave, \nThis po...
# 1    He protecc\nHe attacc\nBut most importantly\nH...
# 2    New YouTube idea : Logan, Mike and David switc...
# 3    I really want to do the treadmill in the pool ...
# 4    You can tell he matured and changed so much, s...
# ..                                                 ...
# 148  I feel like the time I invest doesn't show and...
# 149  Investing time into the game seems 100% pointl...
# 150  I honestly don't feel like my time is valued i...
# 151  I've left the game because of sun sunsetting. ...
# 152  I’m done with this game, too many changes all ...
#
#                         emotion
# 0                      positive
# 1                      positive
# 2                 neutral/other
# 3                      positive
# 4                          love
# ..                          ...
# 148                     sadness
# 149                     sadness
# 150                     sadness
# 151  constructive feedback/idea
# 152                     sadness
#
# [153 rows x 2 columns]

# %% [markdown]
# # Emotions
#
# The categories that will be used for the emotions:
# * Neutral/other
# * Negative (anger/hate/disgust)
# * Positive (joy/happiness/amusement)
# * Constructive feedback/idea
# * Sadness
# * Love
#
# <br>
#
# What needs to be done:
# * check what emotions are in the dataframe
# * count the number of examples for each emotion

# %%
df['emotion'].unique()
# Out:
# array(['positive', 'neutral/other', 'love', 'constructive feedback/idea',
#        'sadness', 'negative'], dtype=object)

# %%
plt.figure(figsize=(15, 7), dpi=100)
sns.countplot(x='emotion', data=df)
plt.show()

# %%
df.groupby('emotion').count()
# Out:
#                             text
# emotion
# constructive feedback/idea    23
# love                          28
# negative                      24
# neutral/other                 24
# positive                      30
# sadness                       24
